# %% [markdown]
# <a href="https://colab.research.google.com/github/RudraPramanik/reinforcement-learning-sb3/blob/master/rlsb3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Stable Baselines3, Gymnasium, and necessary rendering tools
# !pip install stable-baselines3[extra] gymnasium[classic_control]
# !apt install swig cmake
# !pip install pyglet==1.5.1
# !pip install 'gymnasium[box2d]'
# !pip install pyvirtualdisplay
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from pyvirtualdisplay import Display
import os
import base64
from IPython import display as ipythondisplay

# Setup virtual display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1906019868.py in <cell line: 0>()
# ----> 1 from pyvirtualdisplay import Display
#       2 import os
#       3 import base64
#       4 from IPython import display as ipythondisplay
#       5
#
# ModuleNotFoundError: No module named 'pyvirtualdisplay'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# Install Stable Baselines3, Gymnasium, and necessary rendering tools
# !pip install stable-baselines3[extra] gymnasium[classic_control]
# !apt install swig cmake
# !pip install pyglet==1.5.1
# !pip install 'gymnasium[box2d]'
# !pip install pyvirtualdisplay  #
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 8.7 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (9,219 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121703 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# ...

# %%
from pyvirtualdisplay import Display
import os
import base64
from IPython import display as ipythondisplay

# Setup virtual display
display = Display(visible=0, size=(1400, 900))
display.start()

print("Virtual display started successfully.")
# Out:
# Virtual display started successfully.

# %%
import gymnasium as gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv


# 1. Setup the environment
env_id = "CartPole-v1"
env = gym.make(env_id, render_mode="rgb_array")
vec_env = DummyVecEnv([lambda: env])

# 2. Instantiate and Train
model = PPO("MlpPolicy", vec_env, verbose=1, device="cuda")
print("Starting training...")
model.learn(total_timesteps=10000)
print("Training finished.")

# 3. Evaluate and Record
# ... [Recording code here] ...
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
# !pip install nbstripout

# %%
# !nbstripout --install
# Out:
# fatal: --local can only be used inside a git repository
# Installation failed: not a git repository!

# %%
git status
# Out:
#   File "/tmp/ipython-input-339777499.py", line 1
#     git status
#         ^
# SyntaxError: invalid syntax
